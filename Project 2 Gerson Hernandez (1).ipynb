# %%
import random
rng = ("WFIDSPQZ", "XHO' 'TTDBFRT", "QQJYF", "ENQD", "DNPK", "CNTR", "EHWHOD", "TSVMOHOF", "XNOCFQGTM")
randomW = random.choice(rng)
print("Current word")
guesses = ''
turns = 10
while turns > 0:
   fail = 0
   for char in randomW:
       if char in guesses:
           print(char)
       else:
           print("_")
           fail += 1          
   if fail == 0:
       print("YAY! You guessed the word ", randomW, "!!")
       print("This was the encrypted message!")
       print("The decoded message says: ", randomW)
       break
        
   guess = input("Guess a letter:")  
   guesses += guess
   if guess not in randomW:
       turns -= 1
       print("Your letter,", guess, " is not in the word.")
       print("You have ", + turns, ' lives left and you have used these letters: ', guessesZZ)
       if turns == 0:
           print("\nYou weren't able to uncover the word")
           print("The word is:", randomW)
# Out:
# Current word
# _
# _
# _
# _
# _
# _
# _
# _
# Guess a letter:E
# Your letter, E  is not in the word.
# You have  9  lives left and you have used these letters:  E
# _
# _
# _
# _
# _
# _
# _
# _
# Guess a letter:Q
# _
# _
# _
# _
# _
# _
# Q
# _
# Guess a letter:U
# Your letter, U  is not in the word.
# You have  8  lives left and you have used these letters:  EQU
# _
# _
# _
# _
# _
# _
# Q
# _
# Guess a letter:Z
# _
# _
# _
# _
# _
# _
# Q
# Z
# Guess a letter:P
# _
# _
# _
# _
# _
# P
# Q
# Z
# Guess a letter:S
# _
# _
# _
# _
# S
# P
# Q
# Z
# Guess a letter:D
# _
# _
# _
# D
# S
# P
# Q
# Z
# Guess a letter:W
# W
# _
# _
# D
# S
# P
# Q
# Z
# Guess a letter:I
# W
# _
# I
# D
# S
# P
# Q
# Z
# Guess a letter:F
# W
# F
# I
# D
# S
# P
# Q
# Z
# YAY! You guessed the word  WFIDSPQZ !!
# This was the encrypted message!
# The decoded message says:  WFIDSPQZ
